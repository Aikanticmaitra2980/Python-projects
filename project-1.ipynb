# %%
import numpy as np

# %%
Students=[]
Marks=[]
student_dict=dict(zip(Students,Marks))

# %%
def studentsf(n):
    for i in range(n):
        temp1=input("Enter Name of the student")
        Students.append(temp1)

# %%
def marks(m):
    for i in range(m):
        temp2=int(input("Enter marks"))
        Marks.append(temp2)

# %%
def stats_student(Marks):
    avg=np.average(Marks)
    maximum=np.max(Marks)
    minimum=np.min(Marks)
    print("Average marks of this class is",avg)
    print("Highest marks of this class is",maximum)
    print("Minimum marks of this class is",minimum)

# %%
def update_dict():
    global student_dict
    student_dict=dict(zip(Students,Marks))

# %%
def remove_student():
    update_dict()
    rstudent = input("Enter name to remove: ")
    if rstudent in student_dict:
        idx = Students.index(rstudent)
        Students.pop(idx)
        Marks.pop(idx)
        update_dict()
        print("Updated list:", student_dict)
    else:
        print("Student not found.")

# %%
def add_student():
    name=input("Enter new Student name:")
    mark=int(input("Enter marks:"))
    Students.append(name)
    Marks.append(mark)
    update_dict()
    print("Student added Succesfully!")
    print(student_dict)

# %%
def show_performance():
    update_dict()
    print(student_dict)

# %%
commands={'student',
         'marks',
         'remove',
         'show_stat',
          'Add',
         'show'}

# %%
n=int(input("Enter Students"))
dicision='Yes'
while(dicision=='Yes'):
    command=input("Enter a command(student,marks,show,Add,remove,show_stat,exit)")
    if command=='student':
        studentsf(n)
    elif command=='show_stat':
        stats_student(Marks)
    elif command=='marks':
        marks(n)
    elif command=='remove':
        remove_student()
    elif command=='show':
        show_performance()
    elif command=='Add':
        add_student()
    elif command=='exit':
        break
    else:
        dicision=input("Wanna go futher more?")
        if dicision=='No':
            break
# Out:
# Enter Students2
# Enter a command(student,marks,show,Add,remove,show_stat,exit)exit
